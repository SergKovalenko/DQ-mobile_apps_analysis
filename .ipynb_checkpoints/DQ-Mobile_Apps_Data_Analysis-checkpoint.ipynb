# %% [markdown]
# # Mobile Applications Data Analysis
#
#
# ### What the project about:
# Analyse the data from Apple Store and Google Play Market. Mobile Applicatoins users, ratings, price etc.
#
# ### Goal of project:
# By analysing the data understand the most profitable application type. Considering this will a be free app with main revenue through in-app ads.

# %% [markdown]
# ## Read data and analyse what valuable we have for our goal

# %%
# Reading data files. Saving data as table structure - arrays of arrays.

import csv

android_aps_data = []
ios_aps_data = []

with open('google-play-store-apps/googleplaystore.csv') as android_aps_data_file:
    csv_reader = csv.reader(android_aps_data_file)
    
    for row in csv_reader:
        android_aps_data.append(row)
        
with open('app-store-apple-data-set-10k-apps/AppleStore.csv') as ios_aps_data_file:
    csv_reader = csv.reader(ios_aps_data_file)
    
    for row in csv_reader:
        ios_aps_data.append(row)

# %%
# Function to explore and investigate data.

def exloreData(dataset, start, stop, print_number_of_rows_and_columns=False):
    for row in dataset[start:stop]:
        print(row)
        print('\n')
        
    if print_number_of_rows_and_columns:
        print('Columns in total: ', len(row[0]))
        print('Rows in total: ', len(dataset))

# %%
# Print android columns names

exloreData(dataset=android_aps_data, start=0, stop=3, print_number_of_rows_and_columns=False)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']

# %% [markdown]
# Possible needed data for us is under columns 'Category'[0], 'Rating'[1], 'Installs'[4], 'Type'[5], 'Content Rating'[7], 'Genres'[8], 'Android Ver'[11]

# %%
# Print ios columns names

exloreData(dataset=ios_aps_data, start=0, stop=3, print_number_of_rows_and_columns=False)
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']

# %% [markdown]
# Possible needed data for us is under columns 'price'[5], 'user_rating'[8], 'cont_rating'[11], 'prime_genre'[12], 'sup_devices.num'[13], 'lang.num'[15]

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Broken data

# %%
print(android_aps_data[10473])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# As we see row number 10473 has no 'Category' row. And all data of this row moved to left. That's means data for this app is broken and it's better to **remove this data item**.

# %%
# removing broken data item

del android_aps_data[10473]

# %% [markdown]
# #### Dublicate data

# %% [markdown]
# Now we need to check is there are duplicates in our data tables.

# %%
def check_for_duplicates(dataset, name_index=0):
    allData = {}
    dups = {}

    for index, data in enumerate(dataset):
        if data[name_index] in allData:
            allData[data[name_index]].append({
                'data': data,
                'index': index,
            })
        else:
            allData[data[name_index]] = [{
                'data': data,
                'index': index
            }]
    
    for key in allData:
        if len(allData[key]) > 1:
            dups[key] = allData[key]

    return dups

# %%
# print all android apps names that have duplicates
android_dups = check_for_duplicates(android_aps_data[1:], 0)

count_dups = 0
for dup in android_dups:
    print('"' + dup + '"', "amount: ",  len(android_dups[dup]))
    count_dups += len(android_dups[dup]) - 1
    
print('Overall duplicates: ', count_dups)
# Out:
# "Coloring book moana" amount:  2
# "Mcqueen Coloring pages" amount:  2
# "UNICORN - Color By Number & Pixel Art Coloring" amount:  2
# "Textgram - write on photos" amount:  2
# "Wattpad 📖 Free Books" amount:  2
# "Amazon Kindle" amount:  2
# "Dictionary - Merriam-Webster" amount:  2
# "NOOK: Read eBooks & Magazines" amount:  2
# "Oxford Dictionary of English : Free" amount:  2
# "Spanish English Translator" amount:  2
# "NOOK App for NOOK Devices" amount:  2
# "Ebook Reader" amount:  2
# "English Dictionary - Offline" amount:  2
# "Docs To Go™ Free Office Suite" amount:  2
# "Google My Business" amount:  3
# "OfficeSuite : Free Office + PDF Editor" amount:  2
# "Curriculum vitae App CV Builder Free Resume Maker" amount:  2
# "Facebook Pages Manager" amount:  2
# "Box" amount:  3
# "Call Blocker" amount:  2
# "ZOOM Cloud Meetings" amount:  2
# "Facebook Ads Manager" amount:  2
# "Quick PDF Scanner + OCR FREE" amount:  3
# "SignEasy | Sign and Fill PDF and other Documents" amount:  2
# "Genius Scan - PDF Scanner" amount:  2
# "Tiny Scanner - PDF Scanner App" amount:  2
# "Fast Scanner : Free PDF Scan" amount:  2
# "Mobile Doc Scanner (MDScan) Lite" amount:  2
# "TurboScan: scan documents and receipts in PDF" amount:  2
# "Tiny Scanner Pro: PDF Doc Scan" amount:  2
# "Zenefits" amount:  2
# "Google Ads" amount:  3
# "Slack" amount:  3
# "FreshBooks Classic" amount:  2
# "Insightly CRM" amount:  2
# "QuickBooks Accounting: Invoicing & Expenses" amount:  3
# "HipChat - Chat Built for Teams" amount:  2
# "Xero Accounting Software" amount:  2
# "MailChimp - Email, Marketing Automation" amount:  2
# "Crew - Free Messaging and Scheduling" amount:  2
# "Asana: organize team projects" amount:  2
# "Google Analytics" amount:  2
# "AdWords Express" amount:  2
# "Accounting App - Zoho Books" amount:  2
# "Invoice & Time Tracking - Zoho" amount:  2
# "join.me - Simple Meetings" amount:  3
# "Invoice 2go — Professional Invoices and Estimates" amount:  2
# "LINE WEBTOON - Free Comics" amount:  2
# "Daily Manga - Comic & Webtoon" amount:  2
# "DC Comics" amount:  2
# "Manga AZ - Manga Comic Reader" amount:  2
# "Messenger – Text and Video Chat for Free" amount:  3
# "WhatsApp Messenger" amount:  3
# "Google Chrome: Fast & Secure" amount:  3
# "Messenger Lite: Free Calls & Messages" amount:  2
# "Gmail" amount:  3
# "Hangouts" amount:  4
# "Viber Messenger" amount:  5
# "Firefox Browser fast & private" amount:  3
# "Yahoo Mail – Stay Organized" amount:  3
# "imo beta free calls and text" amount:  2
# "imo free video calls and chat" amount:  4
# "Opera Mini - fast web browser" amount:  3
# "Opera Browser: Fast and Secure" amount:  3
# "Firefox Focus: The privacy browser" amount:  3
# "Google Voice" amount:  3
# "Chrome Dev" amount:  2
# "Who" amount:  2
# "WeChat" amount:  4
# "UC Browser Mini -Tiny Fast Private & Secure" amount:  3
# "WhatsApp Business" amount:  2
# "Android Messages" amount:  2
# "Telegram" amount:  3
# "Google Duo - High Quality Video Calls" amount:  2
# "Puffin Web Browser" amount:  3
# "UC Browser - Fast Download Private & Secure" amount:  3
# "Microsoft Edge" amount:  2
# "Hangouts Dialer - Call Phones" amount:  2
# "Talkatone: Free Texts, Calls & Phone Number" amount:  2
# "Calls & Text by Mo+" amount:  2
# "free video calls and chat" amount:  3
# "Skype - free IM & video calls" amount:  3
# "Glide - Video Chat Messenger" amount:  2
# "Google Allo" amount:  3
# "Talkray - Free Calls & Texts" amount:  2
# "LINE: Free Calls & Messages" amount:  3
# "BBM - Free Calls & Messages" amount:  2
# "KakaoTalk: Free Calls & Text" amount:  3
# "CM Browser - Ad Blocker , Fast Download , Privacy" amount:  2
# "Web Browser for Android" amount:  2
# "DU Browser—Browse fast & fun" amount:  2
# "CallApp: Caller ID, Blocker & Phone Call Recorder" amount:  2
# "Whoscall - Caller ID & Block" amount:  2
# "Truecaller: Caller ID, SMS spam blocking & Dialer" amount:  2
# "Moco+ - Chat, Meet People" amount:  2
# "Calculator" amount:  2
# "Zoosk Dating App: Meet Singles" amount:  2
# "OkCupid Dating" amount:  3
# "Hily: Dating, Chat, Match, Meet & Hook up" amount:  3
# "Hinge: Dating & Relationships" amount:  2
# "Casual Dating & Adult Singles - Joyride" amount:  2
# "BBW Dating & Plus Size Chat" amount:  3
# "Moco - Chat, Meet People" amount:  3
# "CMB Free Dating App" amount:  2
# "Hot or Not - Find someone right now" amount:  3
# "Chispa, the Dating App for Latino, Latina Singles" amount:  2
# "Clover Dating App" amount:  2
# "Black People Meet Singles Date" amount:  2
# "stranger chat - anonymous chat" amount:  2
# "Blendr - Chat, Flirt & Meet" amount:  2
# "Free Dating Hook Up Messenger" amount:  2
# "Find Real Love — YouLove Premium Dating" amount:  2
# "Once - Quality Matches Every day" amount:  2
# "Cougar Dating Life : Date Older Women Sugar Mummy" amount:  2
# "Howlr" amount:  2
# "Free Dating & Flirt Chat - Choice of Love" amount:  2
# "FastMeet: Chat, Dating, Love" amount:  2
# "Free Dating App - YoCutie - Flirt, Chat & Meet" amount:  2
# "FarmersOnly Dating" amount:  2
# "Dating for 50 plus Mature Singles – FINALLY" amount:  2
# "Sudy – Meet Elite & Rich Single" amount:  2
# "Christian Dating For Free App" amount:  2
# "Just She - Top Lesbian Dating" amount:  3
# "EliteSingles – Dating for Single Professionals" amount:  2
# "Millionaire Match: Rich Singles Dating App" amount:  2
# "Hide App, Private Dating, Safe Chat - PrivacyHider" amount:  2
# "muzmatch: Muslim & Arab Singles, Marriage & Dating" amount:  3
# "Adult Dirty Emojis" amount:  3
# "Free Dating App - Meet Local Singles - Flirt Chat" amount:  2
# "Meet4U - Chat, Love, Singles!" amount:  2
# "Chat Rooms, Avatars, Date - Galaxy" amount:  2
# "Gay Sugar Daddy Dating & Hookup – Sudy Gay" amount:  2
# "Meet24 - Love, Chat, Singles" amount:  2
# "Black White Interracial Dating - Interracial Match" amount:  2
# "FlirtChat - ♥Free Dating/Flirting App♥" amount:  2
# "95Live -SG#1 Live Streaming App" amount:  2
# "BBW Dating & Curvy Singles Chat- LargeFriends" amount:  2
# "iPair-Meet, Chat, Dating" amount:  2
# "Transenger – Ts Dating and Chat for Free" amount:  2
# "O-Star" amount:  3
# "Free Cam Girls - Live Webcam" amount:  2
# "Cardi B Live Stream Video Chat - Prank" amount:  2
# "Live Girls Talk - Free Video Chat" amount:  2
# "Live Talk - Free Text and Video Chat" amount:  2
# "Chat Kids - Chat Room For Kids" amount:  2
# "Girls Live Chat - Free Text & Video Chat" amount:  2
# "Random Video Chat" amount:  2
# "MouseMingle" amount:  2
# "Random Video Chat App With Strangers" amount:  2
# "Duolingo: Learn Languages Free" amount:  7
# "TED" amount:  4
# "Khan Academy" amount:  3
# "Learn English with Wlingua" amount:  2
# "Princess Coloring Book" amount:  2
# "English Grammar Test" amount:  2
# "PBS KIDS Video" amount:  2
# "Babbel – Learn Languages" amount:  4
# "Monster Truck Driver & Racing" amount:  2
# "Game for KIDS: KIDS match'em" amount:  2
# "Lumosity: #1 Brain Games & Cognitive Training App" amount:  2
# "Learn languages, grammar & vocabulary with Memrise" amount:  4
# "Quizlet: Learn Languages & Vocab with Flashcards" amount:  4
# "Udemy - Online Courses" amount:  3
# "Coursera: Online courses" amount:  2
# "edX - Online Courses by Harvard, MIT & more" amount:  2
# "Peak – Brain Games & Training" amount:  2
# "Lynda - Online Training Videos" amount:  2
# "Brilliant" amount:  2
# "CppDroid - C/C++ IDE" amount:  2
# "C Programming" amount:  2
# "Udacity - Lifelong Learning" amount:  2
# "Learn C++" amount:  2
# "Socratic - Math Answers & Homework Help" amount:  2
# "Rosetta Stone: Learn to Speak & Read New Languages" amount:  4
# "Google Classroom" amount:  3
# "Learn 50 languages" amount:  2
# "Mango Languages: Lovable Language Courses" amount:  2
# "busuu: Learn Languages - Spanish, English & More" amount:  4
# "My Class Schedule: Timetable" amount:  2
# "Edmodo" amount:  2
# "ClassDojo" amount:  3
# "HelloTalk — Chat, Speak & Learn Foreign Languages" amount:  2
# "Fuzzy Numbers: Pre-K Number Foundation" amount:  2
# "Toca Life: City" amount:  2
# "Netflix" amount:  5
# "Tubi TV - Free Movies & TV" amount:  3
# "YouTube Kids" amount:  4
# "Google Play Games" amount:  2
# "H TV" amount:  2
# "Viki: Asian TV Dramas & Movies" amount:  3
# "No.Draw - Colors by Number 2018" amount:  2
# "Movies by Flixster, with Rotten Tomatoes" amount:  3
# "IMDb Movies & TV" amount:  3
# "Twitch: Livestream Multiplayer Games & Esports" amount:  2
# "YouTube Gaming" amount:  2
# "Talking Ben the Dog" amount:  2
# "Red Bull TV: Live Sports, Music & Entertainment" amount:  2
# "Fandango Movies - Times + Tickets" amount:  2
# "Food Network" amount:  3
# "Crunchyroll - Everything Anime" amount:  3
# "Crackle - Free TV & Movies" amount:  3
# "CBS - Full Episodes & Live TV" amount:  2
# "STARZ" amount:  3
# "HISTORY: Watch TV Show Full Episodes & Specials" amount:  3
# "Nick" amount:  6
# "VH1" amount:  3
# "FOX NOW - On Demand & Live TV" amount:  3
# "A&E - Watch Full Episodes of TV Shows" amount:  4
# "The CW" amount:  4
# "BET NOW - Watch Shows" amount:  3
# "Hulu: Stream TV, Movies & more" amount:  4
# "HBO NOW: Stream TV & Movies" amount:  4
# "Univision NOW - Live TV and On Demand" amount:  2
# "SHOWTIME" amount:  2
# "Lifetime - Watch Full Episodes & Original Movies" amount:  3
# "Comedy Central" amount:  2
# "CW Seed" amount:  2
# "The NBC App - Watch Live TV and Full Episodes" amount:  2
# "WWE" amount:  2
# "MTV" amount:  2
# "LEGO® TV" amount:  2
# "HBO GO: Stream with TV Package" amount:  2
# "Showtime Anytime" amount:  2
# "PlayKids - Educational cartoons and games for kids" amount:  2
# "FOX" amount:  2
# "Telemundo Now" amount:  2
# "Colorfy: Coloring Book for Adults - Free" amount:  2
# "K PLUS" amount:  2
# "Wells Fargo Mobile" amount:  2
# "Credit Karma" amount:  3
# "BZWBK24 mobile" amount:  2
# "PayPal" amount:  2
# "Capital One® Mobile" amount:  2
# "Google Pay" amount:  4
# "Robinhood - Investing, No Fees" amount:  2
# "Wells Fargo Daily Change" amount:  2
# "Digit Save Money Automatically" amount:  2
# "Acorns - Invest Spare Change" amount:  2
# "Money Lover: Expense Tracker, Budget Planner" amount:  2
# "Simple - Better Banking" amount:  2
# "Mint: Budget, Bills, Finance" amount:  3
# "CNBC: Breaking Business News & Live Market Data" amount:  2
# "E*TRADE Mobile" amount:  2
# "Moneycontrol – Stocks, Sensex, Mutual Funds, IPO" amount:  2
# "McDonald's" amount:  2
# "Dunkin' Donuts" amount:  2
# "Grubhub: Food Delivery" amount:  2
# "Panera Bread" amount:  2
# "Chick-fil-A" amount:  3
# "Starbucks" amount:  2
# "Domino's Pizza USA" amount:  2
# "SONIC Drive-In" amount:  2
# "SUBWAY®" amount:  2
# "Dairy Queen" amount:  2
# "Wendy’s – Food and Offers" amount:  2
# "Postmates Food Delivery: Order Eats & Alcohol" amount:  2
# "Zomato - Restaurant Finder and Food Delivery App" amount:  2
# "BeyondMenu Food Delivery" amount:  2
# "Home Workout - No Equipment" amount:  2
# "Six Pack in 30 Days - Abs Workout" amount:  2
# "Walk with Map My Walk" amount:  2
# "Runtastic Running App & Mile Tracker" amount:  3
# "Nike+ Run Club" amount:  4
# "Calorie Counter - MyFitnessPal" amount:  5
# "Weight Watchers Mobile" amount:  3
# "Endomondo - Running & Walking" amount:  2
# "Runkeeper - GPS Track Run Walk" amount:  2
# "8fit Workouts & Meal Planner" amount:  2
# "Run with Map My Run" amount:  3
# "Weight Loss Running by Verv" amount:  3
# "Workout Trainer: fitness coach" amount:  2
# "Fabulous: Motivate Me! Meditate, Relax, Sleep" amount:  2
# "Nike Training Club - Workouts & Fitness Plans" amount:  3
# "Fitbit Coach" amount:  2
# "Seven - 7 Minute Workout Training Challenge" amount:  2
# "Daily Yoga - Yoga Fitness Plans" amount:  3
# "Pocket Yoga" amount:  2
# "Relax Meditation: Sleep with Sleep Sounds" amount:  2
# "Meditation Music - Relax, Yoga" amount:  2
# "21-Day Meditation Experience" amount:  2
# "Calm - Meditate, Sleep, Relax" amount:  2
# "Relax Melodies: Sleep Sounds" amount:  2
# "Simple Habit Meditation" amount:  2
# "Headspace: Meditation & Mindfulness" amount:  2
# "I’m Expecting - Pregnancy App" amount:  2
# "Period Tracker" amount:  2
# "Lose It! - Calorie Counter" amount:  3
# "Calorie Counter - MyNetDiary" amount:  2
# "10 Best Foods for You" amount:  2
# "MyPlate Calorie Tracker" amount:  2
# "My Diet Diary Calorie Counter" amount:  2
# "Calorie Counter - Macros" amount:  2
# "Calorie Counter by FatSecret" amount:  2
# "Weight Loss Tracker - RecStyle" amount:  2
# "Lark - 24/7 Health Coach" amount:  2
# "MealLogger-Photo Food Journal" amount:  2
# "Health and Nutrition Guide" amount:  2
# "Calorie Counter & Diet Tracker" amount:  2
# "Food Calorie Calculator" amount:  2
# "Runtastic Sleep Better: Sleep Cycle & Smart Alarm" amount:  2
# "Zillow: Find Houses for Sale & Apartments for Rent" amount:  2
# "Apartments & Rentals - Zillow" amount:  2
# "Realtor.com Real Estate: Homes for Sale and Rent" amount:  2
# "Trulia Real Estate & Rentals" amount:  2
# "Houzz Interior Design Ideas" amount:  4
# "Apartment List: Housing, Apt, and Property Rentals" amount:  2
# "Trulia Rent Apartments & Homes" amount:  2
# "Redfin Real Estate" amount:  2
# "realestate.com.au - Buy, Rent & Sell Property" amount:  2
# "Mortgage by Zillow: Calculator & Rates" amount:  2
# "Home Security Camera WardenCam - reuse old phones" amount:  2
# "Apartments.com Rental Search" amount:  2
# "Ruler" amount:  2
# "Cardboard" amount:  2
# "Diary with lock" amount:  2
# "H&M" amount:  2
# "JOANN - Crafts & Coupons" amount:  2
# "Vaniday - Beauty Booking App" amount:  2
# "Fashion in Vogue" amount:  3
# "StyleSeat" amount:  2
# "Brit + Co" amount:  2
# "Wheretoget: Shop in style" amount:  2
# "My Dressing - Fashion closet" amount:  2
# "Chictopia" amount:  2
# "Scarf Fashion Designer" amount:  2
# "Zara" amount:  2
# "ROBLOX" amount:  9
# "Subway Surfers" amount:  6
# "Candy Crush Saga" amount:  7
# "Solitaire" amount:  3
# "Bubble Shooter" amount:  6
# "Hello Kitty Nail Salon" amount:  2
# "slither.io" amount:  6
# "Clash Royale" amount:  4
# "Temple Run 2" amount:  6
# "Pou" amount:  4
# "Helix Jump" amount:  6
# "Block Puzzle" amount:  4
# "Angry Birds Rio" amount:  4
# "Plants vs. Zombies FREE" amount:  5
# "Sonic Dash" amount:  2
# "Candy Crush Soda Saga" amount:  3
# "Zombie Hunter King" amount:  4
# "Clash of Clans" amount:  4
# "Kick the Buddy" amount:  4
# "Block Puzzle Classic Legend !" amount:  2
# "PAC-MAN" amount:  2
# "Super Jim Jump - pixel 3d" amount:  3
# "8 Ball Pool" amount:  7
# "Magic Tiles 3" amount:  4
# "Word Search" amount:  4
# "Granny" amount:  5
# "Angry Birds Classic" amount:  5
# "Flow Free" amount:  5
# "Fishdom" amount:  3
# "Galaxy Attack: Alien Shooter" amount:  3
# "Zombie Tsunami" amount:  5
# "Bubble Shooter 2" amount:  2
# "Barbie™ Fashion Closet" amount:  2
# "Candy Crush Jelly Saga" amount:  2
# "Hill Climb Racing" amount:  4
# "Gardenscapes" amount:  2
# "Zombie Catchers" amount:  6
# "Minion Rush: Despicable Me Official Game" amount:  4
# "Farm Heroes Saga" amount:  5
# "Geometry Dash World" amount:  2
# "My Talking Angela" amount:  4
# "Cut the Rope FULL FREE" amount:  3
# "Sniper 3D Gun Shooter: Free Shooting Games - FPS" amount:  6
# "Cooking Fever" amount:  2
# "Toon Blast" amount:  3
# "Score! Hero" amount:  3
# "Toy Blast" amount:  2
# "Miraculous Ladybug & Cat Noir - The Official Game" amount:  3
# "Wordscapes" amount:  4
# "Garena Free Fire" amount:  4
# "Bowmasters" amount:  6
# "My Talking Tom" amount:  3
# "Rider" amount:  2
# "Talking Tom Gold Run" amount:  4
# "Pixel Art: Color by Number Game" amount:  3
# "Dream League Soccer 2018" amount:  3
# "Fruits Bomb" amount:  2
# "Traffic Racer" amount:  2
# "Hill Climb Racing 2" amount:  2
# "Knife Hit" amount:  2
# "Block Craft 3D: Building Simulator Games For Free" amount:  3
# "Love Balls" amount:  2
# "Hungry Shark Evolution" amount:  3
# "Pokémon GO" amount:  2
# "Color by Number – New Coloring Book" amount:  2
# "PUBG MOBILE" amount:  4
# "Episode - Choose Your Story" amount:  2
# "Run Sausage Run!" amount:  2
# "Castle Clash: Heroes of the Empire US" amount:  2
# "Last Day on Earth: Survival" amount:  2
# "MARVEL Strike Force" amount:  3
# "Harry Potter: Hogwarts Mystery" amount:  2
# "DRAGON BALL LEGENDS" amount:  4
# "Homescapes" amount:  2
# "Merge Dragons!" amount:  2
# "RULES OF SURVIVAL" amount:  2
# "Final Fantasy XV: A New Empire" amount:  2
# "Honkai Impact 3rd" amount:  2
# "The Game of Life" amount:  2
# "Angry Birds 2" amount:  2
# "Fallout Shelter" amount:  2
# "The Sims™ FreePlay" amount:  2
# "Best Fiends - Free Puzzle Game" amount:  2
# "MARVEL Contest of Champions" amount:  2
# "Jurassic World™ Alive" amount:  2
# "Choices: Stories You Play" amount:  2
# "Idle Heroes" amount:  2
# "Dungeon Hunter Champions: Epic Online Action RPG" amount:  2
# "Jewels Star: OZ adventure" amount:  2
# "Crossy Road" amount:  2
# "Swamp Attack" amount:  2
# "Earn to Die 2" amount:  2
# "Hungry Shark World" amount:  2
# "Dude Perfect 2" amount:  2
# "Shadow Fight 2" amount:  2
# "Alto's Adventure" amount:  2
# "DEER HUNTER 2018" amount:  2
# "DEAD TARGET: FPS Zombie Apocalypse Survival Games" amount:  2
# "Anger of stick 5 : zombie" amount:  2
# "DINO HUNTER: DEADLY SHORES" amount:  2
# "Strawberry Shortcake BerryRush" amount:  3
# "Agar.io" amount:  2
# "DC Super Hero Girls™" amount:  4
# "Metal Soldiers 2" amount:  2
# "Candy Bomb" amount:  2
# "Jetpack Joyride" amount:  2
# "Racing in Car 2" amount:  2
# "Dog Run - Pet Dog Simulator" amount:  3
# "Super ABC! Learning games for kids! Preschool apps" amount:  2
# "Baby Panda Care" amount:  2
# "Toca Kitchen 2" amount:  3
# "PJ Masks: Moonlight Heroes" amount:  3
# "Farming Simulator 14" amount:  2
# "Hot Wheels: Race Off" amount:  2
# "Strawberry Shortcake Ice Cream Island" amount:  2
# "DisneyNOW – TV Shows & Games" amount:  3
# "Papumba Academy - Fun Learning For Kids" amount:  3
# "Thomas & Friends: Race On!" amount:  2
# "School of Dragons" amount:  2
# "LEGO® Juniors Create & Cruise" amount:  2
# "Plants vs. Zombies™ Heroes" amount:  2
# "Disney Magic Kingdoms: Build Your Own Magical Park" amount:  2
# "Turbo FAST" amount:  2
# "My Little Pony: Harmony Quest" amount:  2
# "Equestria Girls" amount:  3
# "Inside Out Thought Bubbles" amount:  2
# "Monster High™" amount:  2
# "Frozen Free Fall" amount:  3
# "Shopkins World!" amount:  2
# "Masha and the Bear Child Games" amount:  2
# "Chess Free" amount:  2
# "Kids Balloon Pop Game Free 🎈" amount:  2
# "Sounds for Toddlers FREE" amount:  2
# "Elmo Calls by Sesame Street" amount:  3
# "Sago Mini Friends" amount:  3
# "Tee and Mo Bath Time Free" amount:  2
# "Bita and the Animals - Pelos Ares" amount:  2
# "TO-FU Oh!SUSHI" amount:  2
# "DreamWorks Friends" amount:  2
# "Avokiddo Emotions" amount:  2
# "Nighty Night Circus" amount:  2
# "Sago Mini Babies" amount:  2
# "Dr. Panda & Toto's Treehouse" amount:  3
# "Fun Kid Racing - Motocross" amount:  2
# "COOKING MAMA Let's Cook!" amount:  2
# "My Little Pony Celebration" amount:  2
# "Animal Jam - Play Wild!" amount:  2
# "Video Editor" amount:  3
# "Real Racing 3" amount:  2
# "Minecraft" amount:  2
# "Monash Uni Low FODMAP Diet" amount:  2
# "iBP Blood Pressure" amount:  2
# "Pedi STAT" amount:  2
# "ASCCP Mobile" amount:  2
# "Journal Club: Medicine" amount:  2
# "Paramedic Protocol Provider" amount:  2
# "Medical ID - In Case of Emergency (ICE)" amount:  2
# "Human Anatomy Atlas 2018: Complete 3D Human Body" amount:  3
# "Essential Anatomy 3" amount:  2
# "Vargo Anesthesia Mega App" amount:  2
# "EMT Review Plus" amount:  2
# "2017 EMRA Antibiotic Guide" amount:  2
# "IBM Micromedex Drug Info" amount:  2
# "Diabetes & Diet Tracker" amount:  2
# "Block Buddy" amount:  2
# "EMT PASS" amount:  2
# "Cardiac diagnosis (heart rate, arrhythmia)" amount:  3
# "AnatomyMapp" amount:  2
# "Blood Pressure Companion" amount:  2
# "Muscle Premium - Human Anatomy, Kinesiology, Bones" amount:  2
# "Advanced Comprehension Therapy" amount:  2
# "EMT Tutor NREMT-B Study Guide" amount:  2
# "Hospitalist Handbook" amount:  2
# "PTA Content Master" amount:  2
# "A Manual of Acupuncture" amount:  2
# "Teladoc Member" amount:  2
# "Blood Pressure" amount:  3
# "Ovia Fertility Tracker & Ovulation Calculator" amount:  2
# "Anthem Anywhere" amount:  2
# "Youper - AI Therapy" amount:  3
# "1800 Contacts - Lens Store" amount:  2
# "Blood Pressure Log - MyDiary" amount:  2
# "fred's Pharmacy" amount:  2
# "Ada - Your Health Guide" amount:  2
# "mySugr: the blood sugar tracker made just for you" amount:  3
# "All Mental disorders" amount:  2
# "ScriptSave WellRx Rx Discounts" amount:  2
# "MoodSpace" amount:  2
# "Super Hearing Super Ear Amplifier" amount:  2
# "Free Blood Pressure" amount:  3
# "Banfield Pet Health Tracker" amount:  2
# "Nurse Grid" amount:  2
# "EMT-B Pocket Prep" amount:  2
# "Diabetes:M" amount:  2
# "FP Notebook" amount:  2
# "PMHNP-BC Pocket Prep" amount:  2
# "JH Blood Pressure Monitor" amount:  2
# "Sway Medical" amount:  2
# "Penn State Health OnDemand" amount:  2
# "Breastfeeding Tracker Baby Log" amount:  2
# "RT 516 VET" amount:  2
# "Maricopa AH" amount:  2
# "CT Scan Cross Sectional Anatomy" amount:  2
# "Anthem BC Anywhere" amount:  2
# "High Blood Pressure Symptoms" amount:  2
# "Blood Pressure(BP) Diary" amount:  2
# "AAFP" amount:  2
# "Airway Ex - Intubate. Anesthetize. Train." amount:  2
# "420 BZ Budeze Delivery" amount:  2
# "Blood Pressure Monitor" amount:  2
# "BP Journal - Blood Pressure Diary" amount:  2
# "Facebook" amount:  2
# "Instagram" amount:  4
# "Facebook Lite" amount:  2
# "Messages, Text and Video Chat for Messenger" amount:  2
# "Tumblr" amount:  3
# "All Social Networks" amount:  2
# "Snapchat" amount:  4
# "Pinterest" amount:  3
# "TextNow - free text + calls" amount:  2
# "Google+" amount:  2
# "Telegram X" amount:  2
# "Who Viewed My Facebook Profile - Stalkers Visitors" amount:  2
# "LiveMe - Video chat, new friends, and make money" amount:  2
# "Amino: Communities and Chats" amount:  2
# "Phone Tracker : Family Locator" amount:  2
# "Periscope - Live Video" amount:  3
# "Quora" amount:  2
# "LinkedIn" amount:  2
# "Meetup" amount:  4
# "Text Free: WiFi Calling App" amount:  3
# "Badoo - Free Chat & Dating App" amount:  4
# "Text free - Free Text + Call" amount:  2
# "textPlus: Free Text & Calls" amount:  2
# "Free phone calls, free texting SMS on free number" amount:  2
# "Tango - Live Video Broadcast" amount:  2
# "MeetMe: Chat & Meet New People" amount:  5
# "Tagged - Meet, Chat & Dating" amount:  2
# "ooVoo Video Calls, Messaging & Stories" amount:  2
# "SayHi Chat, Meet New People" amount:  3
# "Tapatalk - 100,000+ Forums" amount:  2
# "Nextdoor - Local neighborhood news & classifieds" amount:  2
# "SKOUT - Meet, Chat, Go Live" amount:  2
# "We Heart It" amount:  2
# "Couple - Relationship App" amount:  2
# "POF Free Dating App" amount:  3
# "LOVOO" amount:  2
# "Jaumo Dating, Flirt & Live Video" amount:  2
# "Zello PTT Walkie Talkie" amount:  2
# "Dating App, Flirt & Chat : W-Match" amount:  2
# "Amazon for Tablets" amount:  2
# "Wish - Shopping Made Fun" amount:  5
# "AliExpress - Smarter Shopping, Better Living" amount:  4
# "Walmart" amount:  2
# "eBay: Buy & Sell this Summer - Discover Deals Now!" amount:  5
# "letgo: Buy & Sell Used Stuff, Cars & Real Estate" amount:  2
# "Amazon Shopping" amount:  3
# "Flipp - Weekly Shopping" amount:  2
# "CJmall" amount:  2
# "Carousell: Snap-Sell, Chat-Buy" amount:  2
# "ZALORA Fashion Shopping" amount:  2
# "Target - now with Cartwheel" amount:  3
# "Flipkart Online Shopping App" amount:  2
# "Extreme Coupon Finder" amount:  3
# "SnipSnap Coupon App" amount:  2
# "Checkout 51: Grocery coupons" amount:  3
# "Gyft - Mobile Gift Card Wallet" amount:  3
# "The Coupons App" amount:  4
# "Shopkick: Free Gift Cards, Shop Rewards & Deals" amount:  2
# "Ibotta: Cash Back Savings, Rewards & Coupons App" amount:  2
# "RetailMeNot - Coupons, Deals & Discount Shopping" amount:  3
# "Groupon - Shop Deals, Discounts & Coupons" amount:  4
# "Stocard - Rewards Cards Wallet" amount:  2
# "Poshmark - Buy & Sell Fashion" amount:  2
# "Shopular: Coupons, Weekly Ads & Shopping Deals" amount:  2
# "LivingSocial - Local Deals" amount:  3
# "Modcloth – Unique Indie Women's Fashion & Style" amount:  2
# "Fancy" amount:  3
# "JackThreads: Men's Shopping" amount:  3
# "Zappos – Shoe shopping made simple" amount:  2
# "Slickdeals: Coupons & Shopping" amount:  3
# "Wanelo Shopping" amount:  2
# "Etsy: Handmade & Vintage Goods" amount:  2
# "ASOS" amount:  2
# "Overstock – Home Decor, Furniture Shopping" amount:  2
# "Newegg Mobile" amount:  2
# "Shutterfly: Free Prints, Photo Books, Cards, Gifts" amount:  4
# "Google Photos" amount:  4
# "Face Filter, Selfie Editor - Sweet Camera" amount:  2
# "Adobe Photoshop Express:Photo Editor Collage Maker" amount:  2
# "B612 - Beauty & Filter Camera" amount:  3
# "InstaBeauty -Makeup Selfie Cam" amount:  2
# "Camera360 Lite - Selfie Camera" amount:  2
# "YouCam Makeup - Magic Selfie Makeovers" amount:  2
# "BeautyPlus - Easy Photo Editor & Selfie Camera" amount:  5
# "My Photo Keyboard" amount:  2
# "YouCam Perfect - Selfie Photo Editor" amount:  3
# "Open Camera" amount:  3
# "Muzy - Share photos & collages" amount:  2
# "QuickPic - Photo Gallery with Google Drive Support" amount:  3
# "Flickr" amount:  2
# "Camera for Android" amount:  3
# "Photo Editor Selfie Camera Filter & Mirror Image" amount:  2
# "Photo Editor-" amount:  2
# "Cymera Camera- Photo Editor, Filter,Collage,Layout" amount:  4
# "LINE Camera - Photo editor" amount:  2
# "InstaSize Photo Filters & Collage Editor" amount:  2
# "Candy Camera - selfie, beauty camera, photo editor" amount:  3
# "Photo Editor" amount:  2
# "Phogy, 3D Camera" amount:  2
# "Camera360: Selfie Photo Editor with Funny Sticker" amount:  3
# "Blur Image Background" amount:  2
# "Facetune - For Free" amount:  3
# "Camera FV-5 Lite" amount:  2
# "HD Camera for Android" amount:  2
# "Photo Editor Pro" amount:  2
# "Camera MX - Free Photo & Video Camera" amount:  2
# "Camera FV-5" amount:  2
# "No Crop & Square for Instagram" amount:  2
# "FilterGrid - Cam&Photo Editor" amount:  2
# "Photo Editor by Aviary" amount:  2
# "PicsArt Photo Studio: Collage Maker & Pic Editor" amount:  2
# "Z Camera - Photo Editor, Beauty Selfie, Collage" amount:  2
# "ESPN" amount:  7
# "MLB At Bat" amount:  5
# "NFL" amount:  3
# "theScore: Live Sports Scores, News, Stats & Videos" amount:  5
# "FIFA - Tournaments, Soccer News & Live Scores" amount:  2
# "FotMob - Live Soccer Scores" amount:  2
# "Yahoo Fantasy Sports - #1 Rated Fantasy App" amount:  5
# "CBS Sports App - Scores, News, Stats & Watch Live" amount:  8
# "BBC Sport" amount:  2
# "All Football - Latest News & Videos" amount:  2
# "Premier League - Official App" amount:  2
# "ESPN Fantasy Sports" amount:  4
# "Bleacher Report: sports news, scores, & highlights" amount:  6
# "The 5th Stand" amount:  2
# "MLB Ballpark" amount:  2
# "Hole19: Golf GPS App, Rangefinder & Scorecard" amount:  2
# "WatchESPN" amount:  4
# "CBS Sports Fantasy" amount:  2
# "UFC" amount:  2
# "Golfshot: Golf GPS + Tee Times" amount:  2
# "PGA TOUR" amount:  2
# "Fantasy Football" amount:  2
# "US Open Tennis Championships 2018" amount:  2
# "Yahoo Sports - scores, stats, news, & highlights" amount:  3
# "FOX Sports: Live Streaming, Scores & News" amount:  2
# "365Scores - Live Scores" amount:  2
# "Cricbuzz - Live Cricket Scores & News" amount:  2
# "Expedia Hotels, Flights & Car Rental Travel Deals" amount:  4
# "trivago: Hotels & Travel" amount:  3
# "Hopper - Watch & Book Flights" amount:  2
# "KAYAK Flights, Hotels & Cars" amount:  3
# "Skyscanner" amount:  5
# "Hotels.com: Book Hotel Rooms & Find Vacation Deals" amount:  2
# "Booking.com Travel Deals" amount:  3
# "Hostelworld: Hostels & Cheap Hotels Travel App" amount:  2
# "TripAdvisor Hotels Flights Restaurants Attractions" amount:  5
# "Airbnb" amount:  2
# "Maps - Navigate & Explore" amount:  3
# "Offline Maps & Navigation" amount:  2
# "Google Earth" amount:  2
# "Southwest Airlines" amount:  2
# "Google Street View" amount:  2
# "Fly Delta" amount:  2
# "Priceline Hotel Deals, Rental Cars & Flights" amount:  3
# "American Airlines" amount:  3
# "United Airlines" amount:  2
# "British Airways" amount:  2
# "The Emirates App" amount:  2
# "Cheapflights – Flight Search" amount:  2
# "Orbitz - Hotels, Flights & Package Deals" amount:  2
# "HotelTonight: Book amazing deals at great hotels" amount:  3
# "Moto File Manager" amount:  2
# "Google" amount:  2
# "Google Translate" amount:  2
# "Cache Cleaner-DU Speed Booster (booster & cleaner)" amount:  2
# "SHAREit - Transfer & Share" amount:  2
# "Gboard - the Google Keyboard" amount:  3
# "Share Music & Transfer Files - Xender" amount:  2
# "Flashlight" amount:  2
# "CM Flashlight (Compass, SOS)" amount:  2
# "Mobi Calculator free & AD free!" amount:  2
# "VPN Free - Betternet Hotspot VPN & Private Browser" amount:  2
# "osmino Wi-Fi: free WiFi" amount:  2
# "CM Locker - Security Lockscreen" amount:  2
# "Nova Launcher" amount:  2
# "ZEDGE™ Ringtones & Wallpapers" amount:  4
# "CM Launcher 3D - Theme, Wallpapers, Efficient" amount:  2
# "Smart Launcher 5" amount:  2
# "Apex Launcher" amount:  3
# "Yandex Browser with Protect" amount:  2
# "Ringtone Maker" amount:  2
# "Beautiful Widgets Pro" amount:  2
# "Beautiful Widgets Free" amount:  2
# "HD Widgets" amount:  2
# "Backgrounds HD (Wallpapers)" amount:  2
# "ai.type Free Emoji Keyboard" amount:  2
# "GO Keyboard - Emoticon keyboard, Free Theme, GIF" amount:  2
# "Microsoft Word" amount:  3
# "Adobe Acrobat Reader" amount:  3
# "Google Drive" amount:  4
# "QR Scanner & Barcode Scanner 2018" amount:  2
# "Chrome Beta" amount:  2
# "Microsoft Outlook" amount:  2
# "Google PDF Viewer" amount:  3
# "Microsoft Excel" amount:  2
# "Microsoft OneDrive" amount:  2
# "Microsoft OneNote" amount:  3
# "Google Keep" amount:  4
# "ES File Explorer File Manager" amount:  3
# "Dropbox" amount:  3
# "Google Calendar" amount:  3
# "Google Docs" amount:  3
# "Evernote – Organizer, Planner for Notes & Memos" amount:  4
# "Microsoft PowerPoint" amount:  2
# "Do It Later: Tasks & To-Dos" amount:  2
# "myAT&T" amount:  2
# "MEGA" amount:  2
# "TickTick: To Do List with Reminder, Day Planner" amount:  2
# "Wunderlist: To-Do List & Tasks" amount:  3
# "Planner Pro-Personal Organizer" amount:  2
# "Todoist: To-do lists for task management & errands" amount:  3
# "Any.do: To-do list, Calendar, Reminders & Planner" amount:  3
# "CM FILE MANAGER HD" amount:  2
# "Google Sheets" amount:  2
# "Polaris Office - Word, Docs, Sheets, Slide, PDF" amount:  2
# "WPS Office - Word, Docs, PDF, Note, Slide & Sheet" amount:  2
# "ColorNote Notepad Notes" amount:  2
# "Notepad & To do list" amount:  2
# "To-Do Calendar Planner" amount:  2
# "G Cloud Backup" amount:  2
# "AccuWeather: Daily Forecast & Live Weather Reports" amount:  2
# "wetter.com - Weather and Radar" amount:  2
# "Weather by eltiempo.es" amount:  2
# "YouTube" amount:  2
# "Video Downloader" amount:  2
# "Motorola FM Radio" amount:  2
# "Video Player All Format" amount:  2
# "VLC for Android" amount:  2
# "YouTube Studio" amount:  2
# "Vigo Video" amount:  2
# "PowerDirector Video Editor App: 4K, Slow Mo & More" amount:  2
# "Cartoon Network App" amount:  2
# "MX Player" amount:  3
# "Fox News – Breaking News, Live Video & News Alerts" amount:  3
# "BBC News" amount:  3
# "CNN Breaking US & World News" amount:  3
# "Google News" amount:  4
# "Topbuzz: Breaking News, Videos & Funny GIFs" amount:  2
# "Twitter" amount:  3
# "Flipboard: News For Our Time" amount:  3
# "Podcast App: Free & Offline Podcasts by Player FM" amount:  2
# "BuzzFeed: News, Tasty, Quizzes" amount:  2
# "USA TODAY" amount:  3
# "The Wall Street Journal: Business & Market News" amount:  2
# "NYTimes - Latest News" amount:  3
# "NPR News" amount:  2
# "Reuters News" amount:  2
# "Haystack TV: Local & World News - Free" amount:  2
# "ABC News - US & World News" amount:  2
# "NBC News" amount:  2
# "AP Mobile - Breaking News" amount:  2
# "Newsroom: News Worth Sharing" amount:  2
# "AC - Tips & News for Android™" amount:  2
# "Waze - GPS, Maps, Traffic Alerts & Live Navigation" amount:  2
# "Transit: Real-Time Transit App" amount:  2
# "Mapy.cz - Cycling & Hiking offline maps" amount:  2
# "Uber" amount:  2
# "Moovit: Bus Time & Train Time Live Info" amount:  2
# "Maps & GPS Navigation — OsmAnd" amount:  2
# Overall duplicates:  1181

# %% [markdown]
# To remove less needed duplicates, we need to decide how to prioritize them. My understanding that first priority is 'Version' of application. . If versions of duplicates are same, then use 'Reviews'.

# %%
# needed to compare versions
from distutils.version import LooseVersion
indexes_to_remove = []

for name, apps in android_dups.items():
    latest_app = None
    for app in apps:
        if not latest_app:
            latest_app = app
        elif ((latest_app['data'][11] != 'Varies with device' and app['data'][11] != 'Varies with device') 
              and LooseVersion(latest_app['data'][11]) < LooseVersion(app['data'][11])):
            latest_app = app
            indexes_to_remove.append(latest_app['index'] + 1)
        elif latest_app['data'][3] < app['data'][3]:
            latest_app = app
            indexes_to_remove.append(latest_app['index'] + 1)
        else:
            indexes_to_remove.append(app['index'] + 1)
            
# removed founded indexes
for index in sorted(indexes_to_remove, reverse=True):
    del android_aps_data[index]

# check that there is no duplicates
len(check_for_duplicates(android_aps_data[1:], 0)) == 0
# Out:
# True

# %%
# print all ios apps names that have duplicates
ios_dups = check_for_duplicates(ios_aps_data[1:], 2)

for dup in ios_dups:
    print('"' + dup + '"', "amount: ",  len(ios_dups[dup]))
# Out:
# "VR Roller Coaster" amount:  2
# "Mannequin Challenge" amount:  2
