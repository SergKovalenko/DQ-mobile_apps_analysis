# %% [markdown]
# # Mobile Applications Data Analysis
#
#
# ### What the project about:
# Analyse the data from Apple Store and Google Play Market. Mobile Applicatoins users, ratings, price etc.
#
# ### Goal of project:
# By analysing the data understand the most profitable application type. Considering this will a be free app with main revenue through in-app ads.

# %% [markdown]
# ## Read data and analyse what valuable we have for our goal

# %%
# Reading data files. Saving data as table structure - arrays of arrays.

import csv

android_aps_data = []
ios_aps_data = []

with open('google-play-store-apps/googleplaystore.csv') as android_aps_data_file:
    csv_reader = csv.reader(android_aps_data_file)
    
    for row in csv_reader:
        android_aps_data.append(row)
        
with open('app-store-apple-data-set-10k-apps/AppleStore.csv') as ios_aps_data_file:
    csv_reader = csv.reader(ios_aps_data_file)
    
    for row in csv_reader:
        ios_aps_data.append(row)

# %%
# Function to explore and investigate data.

def exloreData(dataset, start, stop, print_number_of_rows_and_column=False):
    for row in dataset[start:stop]:
        print(row)
        print('\n')
        
    if print_number_of_rows_and_columns:
        print('Columns in total: ', len(row[0]))
        print('Rows in total: ', len(dataset))

# %%
# Print android columns names

exloreData(dataset=android_aps_data, start=0, stop=3, print_number_of_rows_and_columns=False)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']

# %% [markdown]
# Possible needed data for us is under columns 'Category'[0], 'Rating'[1], 'Installs'[4], 'Type'[5], 'Content Rating'[7], 'Genres'[8], 'Android Ver'[11]

# %%
# Print ios columns names

exloreData(dataset=ios_aps_data, start=0, stop=3, print_number_of_rows_and_columns=False)
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']

# %% [markdown]
# Possible needed data for us is under columns 'price'[5], 'user_rating'[8], 'cont_rating'[11], 'prime_genre'[12], 'sup_devices.num'[13], 'lang.num'[15]

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Broken data

# %%
print(android_aps_data[10473])
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# As we see row number 10473 has no 'Category' row. And all data of this row moved to left. That's means data for this app is broken and it's better to **remove this data item**.

# %%
# removing broken data item

del android_aps_data[10473]

# %% [markdown]
# #### Dublicate data

# %% [markdown]
# Now we need to check is there are duplicates in our data tables.

# %%
def check_for_duplicates(dataset, name_index=0):
    dups = {}
    names = []
    
    for index, data in enumerate(dataset):
        if not data[name_index] in names:
            names.append(data[name_index])
        else:
            if data[name_index] in dups:
                dups[data[name_index]].data.append({
                    'data': data,
                    'index': index,
                })
                dups[data[name_index]].amount += 1
            else:
                dups[data[name_index]] = {
                    'data': [{
                        'data': data,
                        'index': index
                    }],
                    'amount': 1
                }
            
    return dups, names
# Out:
#   File "<ipython-input-55-1ac473d7461f>", line 13
#     'amount':  dups[data[name_index]].amount += 1
#                                               ^
# SyntaxError: invalid syntax

# %%
dups, names = check_for_duplicates(android_aps_data, 0)
print(dups)
# Out:
# {'Quick PDF Scanner + OCR FREE': [{'data': ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up'], 'index': 230}, {'data': ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up'], 'index': 286}], 'Box': [{'data': ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device'], 'index': 237}, {'data': ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device'], 'index': 266}], 'Google My Business': [{'data': ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up'], 'index': 240}, {'data': ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up'], 'index': 269}], 'ZOOM Cloud Meetings': [{'data': ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '4.1.28165.0716', '4.0 and up'], 'index': 257}], 'join.me - Simple Meetings': [{'data': ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up'], 'index': 262}, {'data': ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up'], 'index': 283}], 'Zenefits': [{'data': ['Zenefits', 'BUSINESS', '4.2', '296', '14M', '50,000+', 'Free', '0', 'Everyone', 'Business', 'June 15, 2018', '3.2.1', '4.1 and up'], 'index': 267}], 'Google Ads': [{'data': ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up'], 'index': 268}, {'data': ['Google Ads', 'BUSINESS', '4.3', '29331', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up'], 'index': 4980}], 'Slack': [{'data': ['Slack', 'BUSINESS', '4.4', '51507', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device'], 'index': 270}, {'data': ['Slack', 'BUSINESS', '4.4', '51510', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device'], 'index': 295}], 'FreshBooks Classic': [{'data': ['FreshBooks Classic', 'BUSINESS', '4.1', '1802', '26M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'April 18, 2018', '1.7.14', '4.2 and up'], 'index': 271}], 'Insightly CRM': [{'data': ['Insightly CRM', 'BUSINESS', '3.8', '1383', '51M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 12, 2018', '3.24.1', '5.0 and up'], 'index': 272}], 'QuickBooks Accounting: Invoicing & Expenses': [{'data': ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 13, 2018', '18.7', '4.1 and up'], 'index': 273}, {'data': ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 13, 2018', '18.7', '4.1 and up'], 'index': 297}], 'HipChat - Chat Built for Teams': [{'data': ['HipChat - Chat Built for Teams', 'BUSINESS', '3.8', '5868', '20M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 3, 2018', '3.19.005', '4.1 and up'], 'index': 274}], 'Xero Accounting Software': [{'data': ['Xero Accounting Software', 'BUSINESS',  ...
